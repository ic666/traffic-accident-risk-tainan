# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import seaborn as sns

# %%
df = pd.read_csv('combined.csv')
df.head()
# Out:
#    Unnamed: 0             案件編號       date      time       GPS經度      GPS緯度  \
# 0           0  10901AC191A0006   1/9/2020  19:55:46  120.220595  22.968235
# 1           1  10901AC191A0017  1/19/2020  23:58:26  120.239389  22.988985
# 2           2  10901AC191B0006   1/1/2020   8:56:03  120.226514  22.999854
# 3           3  10901AC191B0013   1/1/2020  12:20:30  120.226176  22.985547
# 4           4  10901AC191B0037   1/1/2020  21:14:14  120.224018  22.993506
#
#   案件類別名稱 地址類型名稱                發生縣市名稱  die in 24hrs  ...  速限-第1當事者  道路型態大類別名稱  \
# 0   交通事故     其他    臺南市東區段崇興路上(近崇聖路二段)             1  ...        40       單路部分
# 1   交通事故   交叉路口        臺南市東區裕農路段口裕農三街             1  ...        50        交岔路
# 2   交通事故   交叉路口  臺南市東區小東路段132口小東路1986             0  ...        30        交岔路
# 3   交通事故   交叉路口       臺南市東區裕農路段口裕農路43             0  ...        50        交岔路
# 4   交通事故   交叉路口     臺南市東區林森路2段口長榮路366             0  ...        40        交岔路
#
#   事故位置大類別名稱         號誌-號誌種類名稱 事故類型及型態大類別名稱 肇因研判子類別名稱-主要 time slot months a1  \
# 0        路段               無號誌      人與汽(機)車      未注意車前狀態        19      1  1
# 1      交叉路口  行車管制號誌(附設行人專用號誌)          車與車       未依規定讓車        23      1  1
# 2      交叉路口               無號誌          車與車       未依規定讓車         8      1  0
# 3      交叉路口            行車管制號誌          車與車       未依規定讓車        12      1  0
# 4      交叉路口  行車管制號誌(附設行人專用號誌)          車與車    違反號誌管制或指揮        21      1  0
#
#    cause
# 0      2
# 1      1
# 2      1
# 3      1
# 4      5
#
# [5 rows x 23 columns]

# %%
df['天候名稱'].value_counts()
# Out:
# 晴      89040
# 雨       6067
# 陰       5153
# 霧或煙       63
# 暴雨        47
# 強風        13
# 風沙         5
# Name: 天候名稱, dtype: int64

# %%
fig, ax = plt.subplots()

for i in range(1, 9):
    sns.catplot('time slot', 
                hue='cause', 
                data=df[(df['cause'] == i)], 
                kind='count', 
                palette={1: 'red', 2: 'orange', 3: 'yellow', 4: 'green', 5: 'blue', 6: 'purple', 7: 'pink', 8: 'gray'}, 
                ax=ax)

'''
1
未依規定讓車

2
未注意車前狀態

3
其他引起事故之違規或不當行為

4
違反特定標誌(線)禁制

5
違反號誌管制或指揮
左轉彎未依規定
右轉彎未依規定
迴轉未依規定

6
未保持行車安全距離
未保持行車安全間隔
變換車道或方向不當
逆向行駛
橫越道路不慎
違規超車
未靠右行駛

7
酒醉(後)駕駛失控

8
All the rest
'''
# Out:
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try countplot
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try countplot
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try countplot
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try countplot
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try countplot
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try countplot
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try countplot
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try countplot
#   warnings.warn(msg, UserWarning)

# %%
for i in range(1, 9):
    sns.catplot('months', 
                hue='cause', 
                data=df[df['cause'] == i], 
                kind='count', 
                ax=ax)
# Out:
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try countplot
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try countplot
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try countplot
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try countplot
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try countplot
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try countplot
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try countplot
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot('months', 
            data=df, 
            kind='count', 
            ax=ax)
# Out:
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try countplot
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot('time slot', 
            data=df[df['cause'] == i], 
            kind='count', 
            ax=ax)
# Out:
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try countplot
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot('天候名稱',  
            data=df, 
            kind='count', 
            ax=ax)
# Out:
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try countplot
#   warnings.warn(msg, UserWarning)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 26228 (\N{CJK UNIFIED IDEOGRAPH-6674}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 38512 (\N{CJK UNIFIED IDEOGRAPH-9670}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 38695 (\N{CJK UNIFIED IDEOGRAPH-9727}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 25110 (\N{CJK UNIFIED IDEOGRAPH-6216}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 29017 (\N{CJK UNIFIED IDEOGRAPH-7159}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 38632 (\N{CJK UNIFIED IDEOGRAPH-96E8}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 39080 (\N{CJK UNIFIED IDEOGRAPH-98A8}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 27801 (\N{CJK UNIFIED IDEOGRAPH-6C99}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 24375 (\N{CJK UNIFIED IDEOGRAPH-5F37}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 26292 (\N{CJK UNIFIED IDEOGRAPH-66B4}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 22825 (\N{CJK UNIFIED IDEOGRAPH-5929}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 20505 (\N{CJK UNIFIED IDEOGRAPH-5019}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 21517 (\N{CJK UNIFIED IDEOGRAPH-540D}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\seaborn\axisgrid.py:88: UserWarning: Glyph 31281 (\N{CJK UNIFIED IDEOGRAPH-7A31}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 22825 (\N{CJK UNIFIED IDEOGRAPH-5929}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 20505 (\N{CJK UNIFIED IDEOGRAPH-5019}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 21517 (\N{CJK UNIFIED IDEOGRAPH-540D}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 31281 (\N{CJK UNIFIED IDEOGRAPH-7A31}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 26228 (\N{CJK UNIFIED IDEOGRAPH-6674}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 38512 (\N{CJK UNIFIED IDEOGRAPH-9670}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 38695 (\N{CJK UNIFIED IDEOGRAPH-9727}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 25110 (\N{CJK UNIFIED IDEOGRAPH-6216}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 29017 (\N{CJK UNIFIED IDEOGRAPH-7159}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 38632 (\N{CJK UNIFIED IDEOGRAPH-96E8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 39080 (\N{CJK UNIFIED IDEOGRAPH-98A8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 27801 (\N{CJK UNIFIED IDEOGRAPH-6C99}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 24375 (\N{CJK UNIFIED IDEOGRAPH-5F37}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\envs\tf\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 26292 (\N{CJK UNIFIED IDEOGRAPH-66B4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
